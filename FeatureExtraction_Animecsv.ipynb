# %% [markdown]
# ### **PROJECT 1-(FEATURE EXTRACTION)**
# *Here we'll exratct some features from dataframe to get our required answer*

# %%
import numpy as np
import pandas as pd

# %%
#loading our data
df=pd.read_csv(r'anime.csv')
df
# Out:
#     Rank                                              Title  Score
# 0      1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1      2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2      3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3      4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4      5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05
# 5      6  Gintama'TV (51 eps)Apr 2011 - Mar 2012534,105 ...   9.04
# 6      7  Gintama: The FinalMovie (1 eps)Jan 2021 - Jan ...   9.04
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04
# 8      9  Kaguya-sama wa Kokurasetai: Ultra RomanticTV (...   9.04
# 9     10  Gintama': EnchousenTV (13 eps)Oct 2012 - Mar 2...   9.03
# 10    11  Shingeki no Kyojin: The Final Season - Kankets...   9.03
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02
# 12    13  Bleach: Sennen Kessen-hen - Ketsubetsu-tanTV (...   8.99
# ...

# %%
df.head()  #To see first 5 rows
# Out:
#    Rank                                              Title  Score
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05

# %%
df.tail()  #To see last 5 rows
# Out:
#     Rank                                              Title  Score
# 45    46  Vinland SagaTV (24 eps)Jul 2019 - Dec 20191,40...   8.74
# 46    47  Mushishi Zoku Shou 2nd SeasonTV (10 eps)Oct 20...   8.73
# 47    48  Shouwa Genroku Rakugo Shinjuu: Sukeroku Futata...   8.72
# 48    49  Mob Psycho 100 IIITV (12 eps)Oct 2022 - Dec 20...   8.71
# 49    50  Rurouni Kenshin: Meiji Kenkaku Romantan - Tsui...   8.71

# %% [markdown]
# ### **Q.1 Create a new column for Episoad Count**

# %%
df.loc[0]['Title']
# Out:
# 'Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview'

# %%
#we'll define an function which stores values from '(' to ')'
def ext_episoad(x):
    check=False
    value=""
    for i in x:
        if i==')':
            check=False
            return value
        if i=='(':
            check=True
            continue
        if check==True:
            value+=i

# %%
df['Episoads']=df['Title'].apply(ext_episoad)
df.head()
# Out:
#    Rank                                              Title  Score Episoads
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10   64 eps
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07   24 eps
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06   13 eps
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06   51 eps
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05   10 eps

# %%
#now we want to replace 'eps' to empty space
df['Episoads']=df['Episoads'].str.replace(' eps','')
df.head()
# Out:
#    Rank                                              Title  Score Episoads
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10       64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07       24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06       13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06       51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05       10

# %%
df['Episoads'].loc[0]
# Out:
# '64'

# %%
#since episoad count are in string format we'll convert it into integer format 
df['Episoads']=df['Episoads'].astype(int)
df['Episoads'].loc[0]
# Out:
# np.int64(64)

# %% [markdown]
# ### **Q.2 Make a new column for time stamp**

# %%
df['Title'].loc[0]
# Out:
# 'Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr 2009 - Jul 20103,218,472 membersManga StoreVolume 1€4.58Preview'

# %%
#we have to extract 'Apr 2009 - Jul 2010' this much from each title so we'll make an function
def ext_time(x):
    data=""
    for i in range(len(x)):
        if x[i]==')':
            for j in range(i+1,i+1+len('Apr 2009 - Jul 2010')):
                data+=x[j]
            return data

# %%
df['Time Interval']=df['Title'].apply(ext_time)
df.head()
# Out:
#    Rank                                              Title  Score  Episoads  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#          Time Interval
# 0  Apr 2009 - Jul 2010
# 1  Apr 2011 - Sep 2011
# 2  Oct 2022 - Dec 2022
# 3  Apr 2015 - Mar 2016
# 4  Apr 2019 - Jul 2019

# %%
from datetime import datetime
import numpy as np

def calculate_months(interval_string):
    try:
        # Split the string by ' - ' to get start and end dates
        start_str, end_str = interval_string.split(' - ')
        
        # Convert the string dates to datetime objects (format: Month Year)
        start_date = datetime.strptime(start_str.strip(), '%b %Y')
        end_date = datetime.strptime(end_str.strip(), '%b %Y')
        
        # Calculate the difference in months
        months = (end_date.year - start_date.year) * 12 + (end_date.month - start_date.month)
        return months
    except:
        return np.nan

df['Total Months'] = df['Time Interval'].apply(calculate_months)
df.head()
# Out:
#    Rank                                              Title  Score  Episoads  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#          Time Interval  Total Months
# 0  Apr 2009 - Jul 2010            15
# 1  Apr 2011 - Sep 2011             5
# 2  Oct 2022 - Dec 2022             2
# 3  Apr 2015 - Mar 2016            11
# 4  Apr 2019 - Jul 2019             3

# %% [markdown]
# ### **Q.3 Which anime has the highest Rating**

# %%
#since rating is based on score we will just find highest scored anime
df[df['Score']==df['Score'].max()]
# Out:
#    Rank                                              Title  Score  Episoads  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...    9.1        64
#
#          Time Interval  Total Months
# 0  Apr 2009 - Jul 2010            15

# %% [markdown]
# ### **Q.4 List out top 5 anime with highest rating**

# %%
#since our data is already aranged in high to low format so top 5 rows are highest rated anime
df.head()
# Out:
#    Rank                                              Title  Score  Episoads  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#          Time Interval  Total Months
# 0  Apr 2009 - Jul 2010            15
# 1  Apr 2011 - Sep 2011             5
# 2  Oct 2022 - Dec 2022             2
# 3  Apr 2015 - Mar 2016            11
# 4  Apr 2019 - Jul 2019             3

# %%
#other way to do it 
# Sort by Score in descending order, then take the top 5
top_5_anime = df.sort_values(by='Score', ascending=False).head(5)
top_5_anime
# Out:
#    Rank                                              Title  Score  Episoads  \
# 0     1  Fullmetal Alchemist: BrotherhoodTV (64 eps)Apr...   9.10        64
# 1     2  Steins;GateTV (24 eps)Apr 2011 - Sep 20112,473...   9.07        24
# 2     3  Bleach: Sennen Kessen-henTV (13 eps)Oct 2022 -...   9.06        13
# 3     4  Gintama°TV (51 eps)Apr 2015 - Mar 2016605,113 ...   9.06        51
# 4     5  Shingeki no Kyojin Season 3 Part 2TV (10 eps)A...   9.05        10
#
#          Time Interval  Total Months
# 0  Apr 2009 - Jul 2010            15
# 1  Apr 2011 - Sep 2011             5
# 2  Oct 2022 - Dec 2022             2
# 3  Apr 2015 - Mar 2016            11
# 4  Apr 2019 - Jul 2019             3

# %% [markdown]
# ### **Q.5 Which anime has the highest episoad count**

# %%
#dirct way conditional dataframe
df[df['Episoads']==df['Episoads'].max()]
# Out:
#     Rank                                              Title  Score  Episoads  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94       201
#
#           Time Interval  Total Months
# 15  Apr 2006 - Mar 2010            47

# %% [markdown]
# ### **Q.6 Top 5 anime with highest episoad count**

# %%
#long way as previous
episoad_descending=df.sort_values(by='Episoads',ascending=False)
episoad_descending.head(5)
# Out:
#     Rank                                              Title  Score  Episoads  \
# 15    16  GintamaTV (201 eps)Apr 2006 - Mar 20101,034,41...   8.94       201
# 7      8  Hunter x Hunter TV (148 eps)Oct 2011 - Sep 201...   9.04       148
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
# 42    43  Hajime no IppoTV (75 eps)Oct 2000 - Mar 200255...   8.76        75
# 24    25  MonsterTV (74 eps)Apr 2004 - Sep 20051,041,081...   8.87        74
#
#           Time Interval  Total Months
# 15  Apr 2006 - Mar 2010            47
# 7   Oct 2011 - Sep 2014            35
# 11  Jan 1988 - Mar 1997           110
# 42  Oct 2000 - Mar 2002            17
# 24  Apr 2004 - Sep 2005            17

# %% [markdown]
# ### **Q.7 which is longest running anime (i.e., highest total month)**

# %%
df[df['Total Months']==df['Total Months'].max()]
# Out:
#     Rank                                              Title  Score  Episoads  \
# 11    12  Ginga Eiyuu DensetsuOVA (110 eps)Jan 1988 - Ma...   9.02       110
#
#           Time Interval  Total Months
# 11  Jan 1988 - Mar 1997           110
